# %% [markdown]
# # Base CNN Model Experiments

# %%
import torch
import torch.nn as nn
import torchvision.models as models
from torchvision import datasets, transforms
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from collections import defaultdict
import time

# %% [markdown]
# ## Loading the MNIST Dataset

# %%
def load_mnist_data(train=True):
    return datasets.MNIST(root='./data', train=train, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ]))

# %%
mnist_train = load_mnist_data()

# %%
mnist_test = load_mnist_data(train=False)

# %%
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=100, shuffle=False)

# %%
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=100, shuffle=False)

# %% [markdown]
# ## Visualizing the Dataset

# %%
examples = enumerate(train_loader)
batch_idx, (example_data, example_targets) = next(examples)

label_map = defaultdict(list)
count = 0
for i in range(100):
    label = example_targets[i].item()
    if len(label_map[label]) < 5:
        label_map[label].append(example_data[i][0])
        count += 1
    if count == 50:
        break

# %%
fig = plt.figure(figsize=(12, 12))
count = 0
for i in sorted(label_map.keys()):
    for j in range(5):
        plt.subplot(10, 5, count+1)
        plt.tight_layout()
        plt.imshow(label_map[i][j], cmap='gray', interpolation='none')
        plt.title("Label: {}".format(i))
        plt.xticks([])
        plt.yticks([])
        count += 1
fig

# %% [markdown]
# ## Initializing the DataLoaders

# %%
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=64, shuffle=True)

# %%
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=64, shuffle=True)

# %% [markdown]
# ## Initializing the Models and Default Hyperparameters
#
# There are two parts to this:
#
# 1. The Base CNN model: this is the 3 layer CNN that we train on the default hyperparameter settings.
# 2. The variations: For this part, we choose two different sets of hyperparameters: in my case, I chose two different architectures (VGG16 and SqueezeNet) and two different learning rates.

# %%
# Hyperparameters
batch_size = 64
n_epochs = 10
lr = 0.001

# %% [markdown]
# ### 1. The Base CNN Model (3 Layers)
#
# This is the base model on which we train a subset of the data. The model has 3 layers: a CONV layer, POOL layer, and a Fully Connected layer.

# %%
class BaseCNN(nn.Module):
    def __init__(self):
        super(BaseCNN, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.relu = nn.ReLU()
        self.conv2 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2)
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(64 * 14 * 14, 10)
        self.softmax = nn.Softmax()
        
    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        x = self.conv2(x)
        x = self.pool1(x)
        x = self.flatten(x)
        x = self.fc1(x)
        return x

# %%
model = BaseCNN()

# %%
print(model)
# Out:
# BaseCNN(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu): ReLU()
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=12544, out_features=10, bias=True)
#   (softmax): Softmax(dim=None)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
writer = SummaryWriter('./logs/basecnn-default')

# %%
# Training
start = time.time()
running_loss = 0.0
for epoch in range(n_epochs):
    correct = 0
    for idx, (X, y) in enumerate(train_loader):
        optimizer.zero_grad()
        y_pred = model(X)
        
        loss = criterion(y_pred, y)
        running_loss += loss.item()
        
        loss.backward()
        optimizer.step()
        
        for i, p in enumerate(y_pred):
            if y[i] == torch.max(p.data, 0)[1]:
                correct += 1
        if (idx + 1) % 50 == 0:
            print(f'Epoch: {epoch + 1}/{n_epochs}, Batch {idx+1}/{int(len(mnist_train) / batch_size)}, Train Loss: {running_loss / 50}')
            writer.add_scalar('training loss', running_loss / 50, epoch * len(mnist_train) + idx)
            running_loss = 0.0
    accuracy = correct / len(mnist_train)
    print(f'Epoch: {epoch + 1}/1, Train Acc: {accuracy}')

end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Epoch: 1/10, Batch 50/937, Train Loss: 2.238138699531555
# Epoch: 10/10, Batch 600/937, Train Loss: 0.2573628677427769
# Epoch: 10/10, Batch 650/937, Train Loss: 0.23501530930399894
# Epoch: 10/10, Batch 700/937, Train Loss: 0.22287814661860467
# Epoch: 10/10, Batch 750/937, Train Loss: 0.2075982190668583
# Epoch: 10/10, Batch 800/937, Train Loss: 0.22873186975717544
# Epoch: 10/10, Batch 850/937, Train Loss: 0.23245537251234055
# Epoch: 10/10, Batch 900/937, Train Loss: 0.220483461022377
# Epoch: 10/1, Train Acc: 0.9327166666666666
# Elapsed time: 1125.4433841705322s

# %%
torch.save(model.state_dict(), './models/basecnn-default.pt')

# %%
print(len(mnist_test))
# Out:
# 10000

# %%
# Test
start = time.time()
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1

accuracy = correct / len(mnist_test)
print(f'Test Accuracy: {accuracy}')
end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Test Accuracy: 0.9355
# Elapsed time: 6.482763051986694s

# %% [markdown]
# ### Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
y_true_full = []
y_pred_full = []
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1
        y_true_full.append(y[i])
        y_pred_full.append(torch.max(p.data, 0)[1])

# %%
cf = confusion_matrix(y_true_full, y_pred_full, labels=[i for i in range(10)])

# %%
plt.figure(figsize = (12, 12))
plt.title('Confusion matrix for all 10 digit classes (Base CNN Model)')
sns.heatmap(cf, annot=True)
# Out:
# <AxesSubplot:title={'center':'Confusion matrix for all 10 digit classes (Base CNN Model)'}>

# %% [markdown]
# ### Experiment 2: Outlier Test on the Base CNN Model

# %%
def load_fashion_mnist_data():
    return datasets.FashionMNIST(root='./data', train=True, download=True, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5,), (0.5,))
    ]))

# %%
fashion_mnist = load_fashion_mnist_data()

# %%
fashion_loader = torch.utils.data.DataLoader(fashion_mnist, batch_size=10, shuffle=True)

# %%
images, labels = next(iter(fashion_loader))

# %%
fig = plt.figure(figsize=(12, 12))
for i in range(len(images)):
    plt.subplot(4, 3, i+1)
    plt.tight_layout()
    plt.imshow(images[i][0])
    plt.title(f'Label: {datasets.FashionMNIST.classes[labels[i].item()]}')

# %%
def run_outlier_test(path):
    model = BaseCNN()
    model.load_state_dict(torch.load(path))
    pred_labels = model(images)
    
    fig = plt.figure(figsize=(12, 12))
    classes = datasets.FashionMNIST.classes
    for i in range(len(images)):
        plt.subplot(4, 3, i+1)
        plt.tight_layout()
        plt.imshow(images[i][0])
        curr_pred = torch.max(pred_labels[i], 0)[1]
        plt.title(f'Actual: {classes[labels[i].item()]}, Predicted: {classes[curr_pred]}')

# %%
run_outlier_test('./models/basecnn-default.pt')

# %%
run_outlier_test('./models/basecnn-0.1-5.pt')

# %%
run_outlier_test('./models/basecnn-0.1-8.pt')

# %% [markdown]
# ### Experiment 3: The Base CNN Model with an LR of 0.1 and # Epochs = 5

# %%
train_loader = torch.utils.data.DataLoader(mnist_train, batch_size=64, shuffle=True)

# %%
# Hyperparameters
batch_size = 64
n_epochs = 5
lr = 0.1

# %%
model = BaseCNN()

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
writer = SummaryWriter('./logs/basecnn-0.1-5')

# %%
# Training
start = time.time()
running_loss = 0.0
for epoch in range(n_epochs):
    correct = 0
    for idx, (X, y) in enumerate(train_loader):
        optimizer.zero_grad()
        y_pred = model(X)
        loss = criterion(y_pred, y)
        running_loss += loss.item()
        loss.backward()
        optimizer.step()
        
        for i, p in enumerate(y_pred):
            if y[i] == torch.max(p.data, 0)[1]:
                correct += 1
        if (idx + 1) % 50 == 0:
            print(f'Epoch: {epoch + 1}/{n_epochs}, Batch {idx+1}/{int(len(mnist_train) / batch_size)}, Train Loss: {running_loss / 50}')
            writer.add_scalar('training loss', running_loss / 50, epoch * len(mnist_train) + idx)
            running_loss = 0.0
    accuracy = correct / len(mnist_train)
    print(f'Epoch: {epoch + 1}/1, Train Acc: {accuracy}')

end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Epoch: 1/5, Batch 50/937, Train Loss: 0.4726261430978775
# Epoch: 1/5, Batch 100/937, Train Loss: 0.2795935332775116
# Epoch: 1/5, Batch 150/937, Train Loss: 0.19533200234174727
# Epoch: 1/5, Batch 200/937, Train Loss: 0.16234272696077823
# Epoch: 1/5, Batch 250/937, Train Loss: 0.13048515878617764
# Epoch: 1/5, Batch 300/937, Train Loss: 0.13671571098268032
# Epoch: 1/5, Batch 350/937, Train Loss: 0.11311208486557006
# Epoch: 1/5, Batch 400/937, Train Loss: 0.11339104946702719
# Epoch: 1/5, Batch 450/937, Train Loss: 0.11906391691416501
# Epoch: 1/5, Batch 500/937, Train Loss: 0.09048844199627638
# Epoch: 1/5, Batch 550/937, Train Loss: 0.09165226951241494
# Epoch: 1/5, Batch 600/937, Train Loss: 0.0978086805716157
# Epoch: 1/5, Batch 650/937, Train Loss: 0.08526299199089409
# Epoch: 1/5, Batch 700/937, Train Loss: 0.07575336745008826
# Epoch: 1/5, Batch 750/937, Train Loss: 0.08871186200529337
# Epoch: 1/5, Batch 800/937, Train Loss: 0.07876893429085613
# Epoch: 1/5, Batch 850/937, Train Loss: 0.0795675902441144
# Epoch: 1/5, Batch 900/937, Train Loss: 0.07863741604611278
# Epoch: 1/1, Train Acc: 0.9594
# Epoch: 2/5, Batch 50/937, Train Loss: 0.11911342373117804
# Epoch: 2/5, Batch 100/937, Train Loss: 0.053110519628971814
# Epoch: 2/5, Batch 150/937, Train Loss: 0.06710266507230699
# Epoch: 2/5, Batch 200/937, Train Loss: 0.06030977251008153
# Epoch: 2/5, Batch 250/937, Train Loss: 0.07364670694805682
# Epoch: 2/5, Batch 300/937, Train Loss: 0.06446388561278582
# Epoch: 2/5, Batch 350/937, Train Loss: 0.061997747751884165
# Epoch: 2/5, Batch 400/937, Train Loss: 0.057840330135077236
# Epoch: 2/5, Batch 450/937, Train Loss: 0.06121654295828193
# Epoch: 2/5, Batch 500/937, Train Loss: 0.05896472364664078
# Epoch: 2/5, Batch 550/937, Train Loss: 0.06177941415458918
# Epoch: 2/5, Batch 600/937, Train Loss: 0.06238974262494594
# Epoch: 2/5, Batch 650/937, Train Loss: 0.062209043549373746
# Epoch: 5/5, Batch 100/937, Train Loss: 0.026657610952388496
# Epoch: 5/5, Batch 150/937, Train Loss: 0.03868171569425613
# Epoch: 5/5, Batch 200/937, Train Loss: 0.047981829550117254
# Epoch: 5/5, Batch 250/937, Train Loss: 0.03546713167801499
# Epoch: 5/5, Batch 300/937, Train Loss: 0.029755627054255454
# Epoch: 5/5, Batch 350/937, Train Loss: 0.03789538186043501
# Epoch: 5/5, Batch 400/937, Train Loss: 0.02600728964433074
# Epoch: 5/5, Batch 450/937, Train Loss: 0.03932987403124571
# Epoch: 5/5, Batch 500/937, Train Loss: 0.03844399383990094
# Epoch: 5/5, Batch 550/937, Train Loss: 0.03099379175109789
# Epoch: 5/5, Batch 600/937, Train Loss: 0.04092461601248942
# Epoch: 5/5, Batch 650/937, Train Loss: 0.04157813040073961
# Epoch: 5/5, Batch 700/937, Train Loss: 0.036741814529523256
# Epoch: 5/5, Batch 750/937, Train Loss: 0.0411776713677682
# Epoch: 5/5, Batch 800/937, Train Loss: 0.038234460982494056
# Epoch: 5/5, Batch 850/937, Train Loss: 0.0388658930035308
# Epoch: 5/5, Batch 900/937, Train Loss: 0.029208331224508582
# Epoch: 5/1, Train Acc: 0.9884666666666667
# Elapsed time: 570.096086025238s

# %%
torch.save(model.state_dict(), './models/basecnn-0.1-5.pt')

# %%
# Test
start = time.time()
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1

accuracy = correct / len(mnist_test)
print(f'Test Accuracy: {accuracy}')
end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Test Accuracy: 0.9838
# Elapsed time: 6.675978183746338s

# %%
y_true_full = []
y_pred_full = []
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1
        y_true_full.append(y[i])
        y_pred_full.append(torch.max(p.data, 0)[1])

# %%
cf = confusion_matrix(y_true_full, y_pred_full, labels=[i for i in range(10)])
plt.figure(figsize = (12, 12))
plt.title('Confusion matrix for all 10 digit classes (Base CNN Model)')
sns.heatmap(cf, annot=True)
# Out:
# <AxesSubplot:title={'center':'Confusion matrix for all 10 digit classes (Base CNN Model)'}>

# %%
def train_model(model, name, n_epochs, lr):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr=lr)
    writer = SummaryWriter(f'./logs/{name}')
    
    # Training
    start = time.time()
    running_loss = 0.0
    for epoch in range(n_epochs):
        correct = 0
        for idx, (X, y) in enumerate(train_loader):
            optimizer.zero_grad()
            y_pred = model(X)
            loss = criterion(y_pred, y)
            running_loss += loss.item()
            loss.backward()
            optimizer.step()

            for i, p in enumerate(y_pred):
                if y[i] == torch.max(p.data, 0)[1]:
                    correct += 1
            if (idx + 1) % 50 == 0:
                print(f'Epoch: {epoch + 1}/{n_epochs}, Batch {idx+1}/{int(len(mnist_train) / batch_size)}, Train Loss: {running_loss / 50}')
                writer.add_scalar('training loss', running_loss / 50, epoch * len(mnist_train) + idx)
                running_loss = 0.0
        accuracy = correct / len(mnist_train)
        print(f'Epoch: {epoch + 1}/1, Train Acc: {accuracy}')

    end = time.time()
    print(f'Elapsed time: {end - start}s')
    
    torch.save(model.state_dict(), f'./models/{name}.pt')

# %%
def test_model(model):
    test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=64, shuffle=True)
    # Test
    start = time.time()
    correct = 0
    for idx, (X, y) in enumerate(test_loader):
        y_pred = model(X)    
        for i, p in enumerate(y_pred):
            if y[i] == torch.max(p.data, 0)[1]:
                correct += 1

    accuracy = correct / len(mnist_test)
    print(f'Test Accuracy: {accuracy}')
    end = time.time()
    print(f'Elapsed time: {end - start}s')

# %%
def plot_cf(model):
    y_true_full = []
    y_pred_full = []
    correct = 0
    for idx, (X, y) in enumerate(test_loader):
        y_pred = model(X)    
        for i, p in enumerate(y_pred):
            if y[i] == torch.max(p.data, 0)[1]:
                correct += 1
            y_true_full.append(y[i])
            y_pred_full.append(torch.max(p.data, 0)[1])
    cf = confusion_matrix(y_true_full, y_pred_full, labels=[i for i in range(10)])
    plt.figure(figsize = (12, 12))
    plt.title('Confusion matrix for all 10 digit classes (Base CNN Model)')
    sns.heatmap(cf, annot=True)

# %% [markdown]
# ### Experiment 4: The Base CNN Model with an LR of 0.1 and # Epochs = 8

# %%
model = BaseCNN()

# %%
train_model(model, 'basecnn-0.1-8', 8, 0.1)
# Out:
# Epoch: 1/8, Batch 50/937, Train Loss: 0.8263021019101143
# Epoch: 1/8, Batch 100/937, Train Loss: 0.31144639402627944
# Epoch: 1/8, Batch 150/937, Train Loss: 0.2141619887948036
# Epoch: 1/8, Batch 200/937, Train Loss: 0.15727238193154336
# Epoch: 1/8, Batch 250/937, Train Loss: 0.14721983700990676
# Epoch: 1/8, Batch 300/937, Train Loss: 0.10493755247443914
# Epoch: 1/8, Batch 350/937, Train Loss: 0.12706368379294872
# Epoch: 1/8, Batch 400/937, Train Loss: 0.10555589646100998
# Epoch: 1/8, Batch 450/937, Train Loss: 0.09342397089116275
# Epoch: 1/8, Batch 500/937, Train Loss: 0.0821349262446165
# Epoch: 1/8, Batch 550/937, Train Loss: 0.0853099400177598
# Epoch: 1/8, Batch 600/937, Train Loss: 0.08174338292330503
# Epoch: 1/8, Batch 650/937, Train Loss: 0.07372682692483068
# Epoch: 1/8, Batch 700/937, Train Loss: 0.0791703821811825
# Epoch: 1/8, Batch 750/937, Train Loss: 0.08017427137121558
# Epoch: 1/8, Batch 800/937, Train Loss: 0.07662742231041193
# Epoch: 1/8, Batch 850/937, Train Loss: 0.08729779759421945
# Epoch: 1/8, Batch 900/937, Train Loss: 0.08041391529142856
# Epoch: 1/1, Train Acc: 0.9529333333333333
# Epoch: 2/8, Batch 50/937, Train Loss: 0.0942497884016484
# Epoch: 2/8, Batch 100/937, Train Loss: 0.04779923611320555
# Epoch: 2/8, Batch 150/937, Train Loss: 0.06565052604302764
# Epoch: 2/8, Batch 200/937, Train Loss: 0.0732709866669029
# Epoch: 2/8, Batch 250/937, Train Loss: 0.06763807808980346
# Epoch: 2/8, Batch 300/937, Train Loss: 0.0587207958009094
# Epoch: 2/8, Batch 350/937, Train Loss: 0.059314782535657286
# Epoch: 7/8, Batch 200/937, Train Loss: 0.014540780295501463
# Epoch: 7/8, Batch 250/937, Train Loss: 0.02622175812139176
# Epoch: 7/8, Batch 300/937, Train Loss: 0.023678372639697045
# Epoch: 7/8, Batch 350/937, Train Loss: 0.028968514082953332
# Epoch: 7/8, Batch 400/937, Train Loss: 0.015419525967445225
# Epoch: 7/8, Batch 450/937, Train Loss: 0.023595269198995083
# Epoch: 7/8, Batch 500/937, Train Loss: 0.029180943112587555
# Epoch: 7/8, Batch 550/937, Train Loss: 0.022154823436867446
# Epoch: 7/8, Batch 600/937, Train Loss: 0.0352571367053315
# Epoch: 7/8, Batch 650/937, Train Loss: 0.028188260964816435
# Epoch: 7/8, Batch 700/937, Train Loss: 0.026316900647943838
# Epoch: 7/8, Batch 750/937, Train Loss: 0.023401085317600517
# Epoch: 7/8, Batch 800/937, Train Loss: 0.028602447578159627
# Epoch: 7/8, Batch 850/937, Train Loss: 0.02840414344565943
# Epoch: 7/8, Batch 900/937, Train Loss: 0.019912310314830393
# Epoch: 7/1, Train Acc: 0.9922333333333333
# Epoch: 8/8, Batch 50/937, Train Loss: 0.051652020496549086
# Epoch: 8/8, Batch 100/937, Train Loss: 0.019141496358206497
# Epoch: 8/8, Batch 150/937, Train Loss: 0.016044035167433322
# Epoch: 8/8, Batch 200/937, Train Loss: 0.013614901123801246
# Epoch: 8/8, Batch 250/937, Train Loss: 0.022571252967463807
# Epoch: 8/8, Batch 300/937, Train Loss: 0.01970265294308774
# Epoch: 8/8, Batch 350/937, Train Loss: 0.014949035522295161
# Epoch: 8/8, Batch 400/937, Train Loss: 0.03427865766803734
# Epoch: 8/8, Batch 450/937, Train Loss: 0.01874752095376607
# Epoch: 8/8, Batch 500/937, Train Loss: 0.017901959090377204
# Epoch: 8/8, Batch 550/937, Train Loss: 0.01607467436231673
# Epoch: 8/8, Batch 600/937, Train Loss: 0.021262457539560273
# Epoch: 8/8, Batch 650/937, Train Loss: 0.0249899469781667
# Epoch: 8/8, Batch 700/937, Train Loss: 0.023178341786842794
# Epoch: 8/8, Batch 750/937, Train Loss: 0.01927297276328318
# Epoch: 8/8, Batch 800/937, Train Loss: 0.02437822917010635
# Epoch: 8/8, Batch 850/937, Train Loss: 0.021689219502732157
# Epoch: 8/8, Batch 900/937, Train Loss: 0.022052225776715204
# Epoch: 8/1, Train Acc: 0.9937666666666667
# Elapsed time: 850.3954989910126s

# %%
model = BaseCNN()

# %%
model.load_state_dict(torch.load('./models/basecnn-0.1-8.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=64, shuffle=True)
# Test
start = time.time()
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1

accuracy = correct / len(mnist_test)
print(f'Test Accuracy: {accuracy}')
end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Test Accuracy: 0.986
# Elapsed time: 7.0186333656311035s

# %%
plot_cf(model)

# Epoch: 5/5, Batch 650/937, Train Loss: 0.07825417656451464
# Epoch: 5/5, Batch 700/937, Train Loss: 0.08428315764293075
# Epoch: 5/5, Batch 750/937, Train Loss: 0.07624063720926642
# Epoch: 5/5, Batch 800/937, Train Loss: 0.07694666389375925
# Epoch: 5/5, Batch 850/937, Train Loss: 0.07100951846688985
# Epoch: 5/5, Batch 900/937, Train Loss: 0.06549786744639277
# Epoch: 5/1, Train Acc: 0.9780333333333333
# Elapsed time: 573.2341129779816s

# %%
model = BaseCNN()

# %%
model.load_state_dict(torch.load('./models/basecnn-0.01-5.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=64, shuffle=True)
# Test
start = time.time()
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1

accuracy = correct / len(mnist_test)
print(f'Test Accuracy: {accuracy}')
end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Test Accuracy: 0.9798
# Elapsed time: 6.512987852096558s

# %%
plot_cf(model)

# %% [markdown]
# ### Experiment 6: The Base CNN Model with an LR of 0.01 and # Epochs = 8

# %%
model = BaseCNN()

# %%
train_model(model, 'basecnn-0.01-8', 8, 0.01)
# Out:
# Epoch: 1/8, Batch 50/937, Train Loss: 1.5076163041591644
# Epoch: 1/8, Batch 100/937, Train Loss: 0.622716053724289
# Epoch: 1/8, Batch 150/937, Train Loss: 0.468059179186821
# Epoch: 1/8, Batch 200/937, Train Loss: 0.4239205852150917
# Epoch: 1/8, Batch 250/937, Train Loss: 0.38509546607732775
# Epoch: 1/8, Batch 300/937, Train Loss: 0.3375234803557396
# Epoch: 1/8, Batch 350/937, Train Loss: 0.3499438866972923
# Epoch: 1/8, Batch 400/937, Train Loss: 0.3245355007052422
# Epoch: 1/8, Batch 450/937, Train Loss: 0.35104254245758054
# Epoch: 1/8, Batch 500/937, Train Loss: 0.3289066883921623
# Epoch: 1/8, Batch 550/937, Train Loss: 0.3158382201194763
# Epoch: 1/8, Batch 600/937, Train Loss: 0.32403082042932513
# Epoch: 1/8, Batch 650/937, Train Loss: 0.31438664108514786
# Epoch: 1/8, Batch 700/937, Train Loss: 0.30740679666399956
# Epoch: 1/8, Batch 750/937, Train Loss: 0.2902198266983032
# Epoch: 1/8, Batch 800/937, Train Loss: 0.2722489994764328
# Epoch: 1/8, Batch 850/937, Train Loss: 0.2703132738173008
# Epoch: 1/8, Batch 900/937, Train Loss: 0.2859256461262703
# Epoch: 1/1, Train Acc: 0.8800833333333333
# Epoch: 2/8, Batch 50/937, Train Loss: 0.48346866652369497
# Epoch: 2/8, Batch 100/937, Train Loss: 0.23841110169887542
# Epoch: 2/8, Batch 150/937, Train Loss: 0.27415106385946275
# Epoch: 2/8, Batch 200/937, Train Loss: 0.25721336975693704
# Epoch: 2/8, Batch 250/937, Train Loss: 0.2233814752101898
# Epoch: 2/8, Batch 300/937, Train Loss: 0.247066693007946
# Epoch: 2/8, Batch 350/937, Train Loss: 0.23078984513878822
# Epoch: 7/8, Batch 200/937, Train Loss: 0.05638054717332125
# Epoch: 7/8, Batch 250/937, Train Loss: 0.05652048721909523
# Epoch: 7/8, Batch 300/937, Train Loss: 0.06119699258357286
# Epoch: 7/8, Batch 350/937, Train Loss: 0.06509635390713811
# Epoch: 7/8, Batch 400/937, Train Loss: 0.06895676508545875
# Epoch: 7/8, Batch 450/937, Train Loss: 0.07541142374277116
# Epoch: 7/8, Batch 500/937, Train Loss: 0.0703209038823843
# Epoch: 7/8, Batch 550/937, Train Loss: 0.06594556590542197
# Epoch: 7/8, Batch 600/937, Train Loss: 0.06241440687328577
# Epoch: 7/8, Batch 650/937, Train Loss: 0.06423080037347972
# Epoch: 7/8, Batch 700/937, Train Loss: 0.05876210926100612
# Epoch: 7/8, Batch 750/937, Train Loss: 0.055837785522453484
# Epoch: 7/8, Batch 800/937, Train Loss: 0.059909135699272156
# Epoch: 7/8, Batch 850/937, Train Loss: 0.05477859515696764
# Epoch: 7/8, Batch 900/937, Train Loss: 0.05723000466823578
# Epoch: 7/1, Train Acc: 0.9819833333333333
# Epoch: 8/8, Batch 50/937, Train Loss: 0.1007102447282523
# Epoch: 8/8, Batch 100/937, Train Loss: 0.0679809938184917
# Epoch: 8/8, Batch 150/937, Train Loss: 0.05676624752581119
# Epoch: 8/8, Batch 200/937, Train Loss: 0.05446559557691216
# Epoch: 8/8, Batch 250/937, Train Loss: 0.0533243914693594
# Epoch: 8/8, Batch 300/937, Train Loss: 0.05419161825440824
# Epoch: 8/8, Batch 350/937, Train Loss: 0.061854868549853566
# Epoch: 8/8, Batch 400/937, Train Loss: 0.055050302417948845
# Epoch: 8/8, Batch 450/937, Train Loss: 0.05914117084816098
# Epoch: 8/8, Batch 500/937, Train Loss: 0.04883061122149229
# Epoch: 8/8, Batch 550/937, Train Loss: 0.06412306655198335
# Epoch: 8/8, Batch 600/937, Train Loss: 0.06401879488490522
# Epoch: 8/8, Batch 650/937, Train Loss: 0.05852470500394702
# Epoch: 8/8, Batch 700/937, Train Loss: 0.05390828251373023
# Epoch: 8/8, Batch 750/937, Train Loss: 0.0552479934040457
# Epoch: 8/8, Batch 800/937, Train Loss: 0.05144920453429222
# Epoch: 8/8, Batch 850/937, Train Loss: 0.05180620127357542
# Epoch: 8/8, Batch 900/937, Train Loss: 0.04821811992675066
# Epoch: 8/1, Train Acc: 0.9837166666666667
# Elapsed time: 858.8771398067474s

# %%
model = BaseCNN()

# %%
model.load_state_dict(torch.load('./models/basecnn-0.01-8.pt'))
# Out:
# <All keys matched successfully>

# %%
test_loader = torch.utils.data.DataLoader(mnist_test, batch_size=64, shuffle=True)
# Test
start = time.time()
correct = 0
for idx, (X, y) in enumerate(test_loader):
    y_pred = model(X)    
    for i, p in enumerate(y_pred):
        if y[i] == torch.max(p.data, 0)[1]:
            correct += 1

accuracy = correct / len(mnist_test)
print(f'Test Accuracy: {accuracy}')
end = time.time()
print(f'Elapsed time: {end - start}s')
# Out:
# Test Accuracy: 0.9826
# Elapsed time: 6.5744788646698s

# %%
plot_cf(model)
